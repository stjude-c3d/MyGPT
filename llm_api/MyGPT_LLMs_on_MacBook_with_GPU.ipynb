# %% [markdown]
# You can run this Google Colab notebook by running it from local environmenet and use local GPU to run Llama2 API. Before you start, follow these Jupyter installation and running notebook before going to step 1.
#
# ## Pre requirements
# Step 1: Install <a href='http://jupyter.org/install'>Jupyter</a> on your local machine by following command.
# ```
# pip install notebook
# ```
#
# New notebook servers are started normally, though you will need to set a flag to explicitly trust WebSocket connections from the Colab frontend.
#
# ```
# jupyter notebook \
#     --NotebookApp.allow_origin='https://colab.research.google.com' \
#     --port=8888 \
#     --NotebookApp.port_retries=0
# ```
# Once the server has started, it will print a message with the initial backend URL used for authentication. Make a copy of this URL as you'll need to provide this for step 2 below.
#
# Step 2: Connect to the local runtime
# In Colab, click the "Connect" button and select "Connect to local runtime...". Enter the URL from the previous step in the dialog that appears and click the "Connect" button. After this, you should now be connected to your local runtime.

# %% [markdown]
# ## Run LLM API to use local GPU
# Follow these steps to strat LLM API using Jupyter Notebook:
# 1. Set up the environment

# %%
# !apt update
# !pip install --upgrade pip
# !pip install --upgrade setuptools wheel
# !apt-get install -y build-essential iputils-ping
# Out:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
#
# Requirement already satisfied: pip in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (23.1.2)
# Collecting pip
#   Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.7 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# Successfully installed pip-23.2.1
# Requirement already satisfied: setuptools in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (67.8.0)
# Collecting setuptools
#   Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/bb/26/7945080113158354380a12ce26873dd6c1ebd88d47f5bc24e2c5bb38c16a/setuptools-68.2.2-py3-none-any.whl.metadata
#   Using cached setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: wheel in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (0.38.4)
# Collecting wheel
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/b8/8b/31273bf66016be6ad22bb7345c37ff350276cfd46e389a0c2ac5da9d9073/wheel-0.41.2-py3-none-any.whl.metadata
#   Using cached wheel-0.41.2-py3-none-any.whl.metadata (2.2 kB)
# Using cached setuptools-68.2.2-py3-none-any.whl (807 kB)
# Using cached wheel-0.41.2-py3-none-any.whl (64 kB)
# Installing collected packages: wheel, setuptools
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.38.4
#     Uninstalling wheel-0.38.4:
#       Successfully uninstalled wheel-0.38.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.8.0
#     Uninstalling setuptools-67.8.0:
#       Successfully uninstalled setuptools-67.8.0
# Successfully installed setuptools-68.2.2 wheel-0.41.2

# %% [markdown]
# 2. Install llama-cpp-python to use Llama2

# %%
# !CMAKE_ARGS="-DLLAMA_METAL=on" FORCE_CMAKE=1 pip install llama-cpp-python==0.1.78
# Out:
# Collecting llama-cpp-python==0.1.78
#   Downloading llama_cpp_python-0.1.78.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.8 MB/s eta 0:00:00
# done
# done
# done
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from llama-cpp-python==0.1.78) (4.7.1)
# Collecting numpy>=1.20.0 (from llama-cpp-python==0.1.78)
#   Obtaining dependency information for numpy>=1.20.0 from https://files.pythonhosted.org/packages/0f/a8/5057b97c395a710999b5697ffedd648caee82c24a29595952d26bd750155/numpy-1.25.2-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading numpy-1.25.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting diskcache>=5.6.1 (from llama-cpp-python==0.1.78)
#   Obtaining dependency information for diskcache>=5.6.1 from https://files.pythonhosted.org/packages/3f/27/4570e78fc0bf5ea0ca45eb1de3818a23787af9b390c0b0a0033a1b8236f9/diskcache-5.6.3-py3-none-any.whl.metadata
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Downloading numpy-1.25.2-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 19.2 MB/s eta 0:00:00
# Building wheels for collected packages: llama-cpp-python
# done
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.1.78-cp39-cp39-macosx_13_0_arm64.whl size=669560 sha256=eb62e261d547f4681b6b6648b174683d508718fdb9b72ed0d827233ef0a13379
#   Stored in directory: /Users/jpatel2/Library/Caches/pip/wheels/0c/b7/c5/44bc04b1032871ad214d9e23594bbffeccff9278f98691d8b3
# Successfully built llama-cpp-python
# Installing collected packages: numpy, diskcache, llama-cpp-python
# Successfully installed diskcache-5.6.3 llama-cpp-python-0.1.78 numpy-1.25.2

# %% [markdown]
# 3. Install requirements

# %%
# %cd llm_api
# !pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: 'llm_api'
# /Users/jpatel2/Desktop/github_repos/PubGPT/llm_api
# Requirement already satisfied: Django<4.0,>=3.0 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (3.2.21)
# Requirement already satisfied: psycopg2-binary>=2.8 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (2.9.7)
# Requirement already satisfied: requests>=2.0 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: djangorestframework in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (3.14.0)
# Requirement already satisfied: django-cors-headers in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: python-dotenv in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: asgiref<4,>=3.3.2 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from Django<4.0,>=3.0->-r requirements.txt (line 1)) (3.7.2)
# Requirement already satisfied: pytz in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from Django<4.0,>=3.0->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: sqlparse>=0.2.2 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from Django<4.0,>=3.0->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from requests>=2.0->-r requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from requests>=2.0->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from requests>=2.0->-r requirements.txt (line 3)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from requests>=2.0->-r requirements.txt (line 3)) (2023.5.7)
# Requirement already satisfied: typing-extensions>=4 in /Users/jpatel2/miniconda3/lib/python3.9/site-packages (from asgiref<4,>=3.3.2->Django<4.0,>=3.0->-r requirements.txt (line 1)) (4.7.1)

# %% [markdown]
# 4. Start the server, the api should be running at http://localhost:9000

# %%
# !python manage.py migrate --fake sessions zero
# !ptyhon manage.py migrate --fake-initial
# !python manage.py migrate collectstatic --no-input
# !python manage.py runserver 0.0.0.0:9000
# Out:
# llama.cpp: loading model from ./models/Llama2/llama-2-7b-chat.ggmlv3.q5_K_S.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 6040
# llama_model_load_internal: n_embd     = 4096
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 32
# llama_model_load_internal: n_head_kv  = 32
# llama_model_load_internal: n_layer    = 32
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: n_gqa      = 1
# llama_model_load_internal: rnorm_eps  = 5.0e-06
# llama_model_load_internal: n_ff       = 11008
# llama_model_load_internal: freq_base  = 10000.0
# llama_model_load_internal: freq_scale = 1
# llama_model_load_internal: ftype      = 16 (mostly Q5_K - Small)
# llama_model_load_internal: model size = 7B
# llama_model_load_internal: ggml ctx size =    0.08 MB
# llama_model_load_internal: mem required  = 4435.58 MB (+ 3020.00 MB per state)
# llama_new_context_with_model: kv self size  = 3020.00 MB
# ggml_metal_init: allocating
# ggml_metal_init: loading '/Users/jpatel2/miniconda3/lib/python3.9/site-packages/llama_cpp/ggml-metal.metal'
# ggml_metal_init: loaded kernel_add                            0x104d624a0
# ggml_metal_init: loaded kernel_add_row                        0x104d641f0
# ggml_metal_init: loaded kernel_mul                            0x104d63990
# ggml_metal_init: loaded kernel_mul_row                        0x104d64860
# ggml_metal_init: loaded kernel_scale                          0x104d65000
# ggml_metal_init: loaded kernel_silu                           0x104d65660
# ggml_metal_init: loaded kernel_relu                           0x104d62810
# ggml_metal_init: loaded kernel_gelu                           0x104d62a70
# ggml_metal_init: loaded kernel_soft_max                       0x104d669c0
# ggml_metal_init: loaded kernel_diag_mask_inf                  0x104d66e60
# ggml_metal_init: loaded kernel_get_rows_f16                   0x104d67910
# ggml_metal_init: loaded kernel_get_rows_q4_0                  0x104d680b0
# ggml_metal_init: loaded kernel_get_rows_q4_1                  0x104d69030
# ggml_metal_init: loaded kernel_get_rows_q2_K                  0x104d697b0
# ggml_metal_init: loaded kernel_get_rows_q3_K                  0x104d69ef0
# ggml_metal_init: loaded kernel_get_rows_q4_K                  0x104d6a630
# ggml_metal_init: loaded kernel_get_rows_q5_K                  0x104d6ad70
# ggml_metal_init: loaded kernel_get_rows_q6_K                  0x104d6b4b0
# ggml_metal_init: loaded kernel_rms_norm                       0x104d6bc00
# ggml_metal_init: loaded kernel_norm                           0x104d6c340
# ggml_metal_init: loaded kernel_mul_mat_f16_f32                0x104d6cca0
# ggml_metal_init: loaded kernel_mul_mat_q4_0_f32               0x104d6d4e0
# ggml_metal_init: loaded kernel_mul_mat_q4_1_f32               0x104d6dd20
# ggml_metal_init: loaded kernel_mul_mat_q2_K_f32               0x104d6e700
# ggml_metal_init: loaded kernel_mul_mat_q3_K_f32               0x104d6eef0
# ggml_metal_init: loaded kernel_mul_mat_q4_K_f32               0x104d6f760
# ggml_metal_init: loaded kernel_mul_mat_q5_K_f32               0x104d6ffd0
# ggml_metal_init: loaded kernel_mul_mat_q6_K_f32               0x104d70950
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                 0x104d71460
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                0x104d71c90
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                0x104d724c0
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                0x104d72d40
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                0x104d73570
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                0x104d73de0
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                0x104d74650
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                0x104d74ec0
# ggml_metal_init: loaded kernel_rope                           0x104d754c0
# ggml_metal_init: loaded kernel_alibi_f32                      0x104d75eb0
# ggml_metal_init: loaded kernel_cpy_f32_f16                    0x104d76820
# ggml_metal_init: loaded kernel_cpy_f32_f32                    0x104d77110
# ggml_metal_init: loaded kernel_cpy_f16_f16                    0x104d77a80
# ggml_metal_init: recommendedMaxWorkingSetSize = 49152.00 MB
# ggml_metal_init: hasUnifiedMemory             = true
# ggml_metal_init: maxTransferRate              = built-in GPU
# llama_new_context_with_model: compute buffer total size =  418.85 MB
# llama_new_context_with_model: max tensor size =   102.54 MB
# ggml_metal_add_buffer: allocated 'data            ' buffer, size =  4435.94 MB, ( 4436.38 / 49152.00)
# ggml_metal_add_buffer: allocated 'eval            ' buffer, size =     1.36 MB, ( 4437.73 / 49152.00)
# ggml_metal_add_buffer: allocated 'kv              ' buffer, size =  3022.00 MB, ( 7459.73 / 49152.00)
# ggml_metal_add_buffer: allocated 'alloc           ' buffer, size =   417.52 MB, ( 7877.25 / 49152.00)
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | VSX = 0 |
# Operations to perform:
#   Unapply all migrations: sessions
# Running migrations:
#   No migrations to apply.
#   Your models in app(s): 'testdb' have changes that are not yet reflected in a migration, and so won't be applied.
#   Run 'manage.py makemigrations' to make new migrations, and then re-run 'manage.py migrate' to apply them.
# /bin/bash: ptyhon: command not found
# llama.cpp: loading model from ./models/Llama2/llama-2-7b-chat.ggmlv3.q5_K_S.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 6040
# llama_model_load_internal: n_embd     = 4096
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 32
# llama_model_load_internal: n_head_kv  = 32
# llama_model_load_internal: n_layer    = 32
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: n_gqa      = 1
# llama_model_load_internal: rnorm_eps  = 5.0e-06
# llama_model_load_internal: n_ff       = 11008
# llama_model_load_internal: freq_base  = 10000.0
# llama_model_load_internal: freq_scale = 1
# llama_model_load_internal: ftype      = 16 (mostly Q5_K - Small)
# llama_model_load_internal: model size = 7B
# llama_model_load_internal: ggml ctx size =    0.08 MB
# llama_model_load_internal: mem required  = 4435.58 MB (+ 3020.00 MB per state)
# llama_new_context_with_model: kv self size  = 3020.00 MB
# ggml_metal_init: allocating
# ggml_metal_init: loading '/Users/jpatel2/miniconda3/lib/python3.9/site-packages/llama_cpp/ggml-metal.metal'
# ggml_metal_init: loaded kernel_add                            0x138f13bd0
# ggml_metal_init: loaded kernel_add_row                        0x138f15940
# ggml_metal_init: loaded kernel_mul                            0x138f150c0
# ggml_metal_init: loaded kernel_mul_row                        0x138f15fa0
# ggml_metal_init: loaded kernel_scale                          0x138f16730
# ggml_metal_init: loaded kernel_silu                           0x138f16d90
# ggml_metal_init: loaded kernel_relu                           0x138f13f40
# ggml_metal_init: loaded kernel_gelu                           0x138f141a0
# ggml_metal_init: loaded kernel_soft_max                       0x138f180b0
# ggml_metal_init: loaded kernel_diag_mask_inf                  0x138f18550
# ggml_metal_init: loaded kernel_get_rows_f16                   0x138f19010
# ggml_metal_init: loaded kernel_get_rows_q4_0                  0x138f19780
# ggml_metal_init: loaded kernel_get_rows_q4_1                  0x138f1a720
# ggml_metal_init: loaded kernel_get_rows_q2_K                  0x138f1ae50
# ggml_metal_init: loaded kernel_get_rows_q3_K                  0x138f1b590
# ggml_metal_init: loaded kernel_get_rows_q4_K                  0x138f1bc60
# ggml_metal_init: loaded kernel_get_rows_q5_K                  0x138f1c440
# ggml_metal_init: loaded kernel_get_rows_q6_K                  0x138f1cb10
# ggml_metal_init: loaded kernel_rms_norm                       0x138f1d2d0
# ggml_metal_init: loaded kernel_norm                           0x138f1da10
# ggml_metal_init: loaded kernel_mul_mat_f16_f32                0x138f1e3d0
# ggml_metal_init: loaded kernel_mul_mat_q4_0_f32               0x138f1ebf0
# ggml_metal_init: loaded kernel_mul_mat_q4_1_f32               0x138f1f430
# ggml_metal_init: loaded kernel_mul_mat_q2_K_f32               0x138f1fdf0
# ggml_metal_init: loaded kernel_mul_mat_q3_K_f32               0x138f205c0
# ggml_metal_init: loaded kernel_mul_mat_q4_K_f32               0x138f20e30
# ggml_metal_init: loaded kernel_mul_mat_q5_K_f32               0x138f216a0
# ggml_metal_init: loaded kernel_mul_mat_q6_K_f32               0x138f22020
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                 0x138f22b30
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                0x138f23360
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                0x138f23bd0
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                0x138f24440
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                0x138f24cc0
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                0x138f254f0
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                0x138f25d20
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                0x138f26590
# ggml_metal_init: loaded kernel_rope                           0x138f26bd0
# ggml_metal_init: loaded kernel_alibi_f32                      0x138f27540
# ggml_metal_init: loaded kernel_cpy_f32_f16                    0x138f27eb0
# ggml_metal_init: loaded kernel_cpy_f32_f32                    0x138f28820
# ggml_metal_init: loaded kernel_cpy_f16_f16                    0x138f29110
# ggml_metal_init: recommendedMaxWorkingSetSize = 49152.00 MB
# ggml_metal_init: hasUnifiedMemory             = true
# ggml_metal_init: maxTransferRate              = built-in GPU
# llama_new_context_with_model: compute buffer total size =  418.85 MB
# llama_new_context_with_model: max tensor size =   102.54 MB
# ggml_metal_add_buffer: allocated 'data            ' buffer, size =  4435.94 MB, ( 4436.38 / 49152.00)
# ggml_metal_add_buffer: allocated 'eval            ' buffer, size =     1.36 MB, ( 4437.73 / 49152.00)
# ggml_metal_add_buffer: allocated 'kv              ' buffer, size =  3022.00 MB, ( 7459.73 / 49152.00)
# ggml_metal_add_buffer: allocated 'alloc           ' buffer, size =   417.52 MB, ( 7877.25 / 49152.00)
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | VSX = 0 |
# CommandError: No installed app with label 'collectstatic'.
# llama.cpp: loading model from ./models/Llama2/llama-2-7b-chat.ggmlv3.q5_K_S.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 6040
# llama_model_load_internal: n_embd     = 4096
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 32
# llama_model_load_internal: n_head_kv  = 32
# llama_model_load_internal: n_layer    = 32
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: n_gqa      = 1
# llama_model_load_internal: rnorm_eps  = 5.0e-06
# llama_model_load_internal: n_ff       = 11008
# llama_model_load_internal: freq_base  = 10000.0
# llama_model_load_internal: freq_scale = 1
# llama_model_load_internal: ftype      = 16 (mostly Q5_K - Small)
# llama_model_load_internal: model size = 7B
# llama_model_load_internal: ggml ctx size =    0.08 MB
# llama_model_load_internal: mem required  = 4435.58 MB (+ 3020.00 MB per state)
# llama_new_context_with_model: kv self size  = 3020.00 MB
# ggml_metal_init: allocating
# ggml_metal_init: loading '/Users/jpatel2/miniconda3/lib/python3.9/site-packages/llama_cpp/ggml-metal.metal'
# ggml_metal_init: loaded kernel_add                            0x10749b5a0
# ggml_metal_init: loaded kernel_add_row                        0x10749d310
# ggml_metal_init: loaded kernel_mul                            0x10749ca90
# ggml_metal_init: loaded kernel_mul_row                        0x10749d970
# ggml_metal_init: loaded kernel_scale                          0x10749e100
# ggml_metal_init: loaded kernel_silu                           0x10749e760
# ggml_metal_init: loaded kernel_relu                           0x10749b910
# ggml_metal_init: loaded kernel_gelu                           0x10749bb70
# ggml_metal_init: loaded kernel_soft_max                       0x10749fa80
# ggml_metal_init: loaded kernel_diag_mask_inf                  0x10749ff20
# ggml_metal_init: loaded kernel_get_rows_f16                   0x1074a09e0
# ggml_metal_init: loaded kernel_get_rows_q4_0                  0x1074a1110
# ggml_metal_init: loaded kernel_get_rows_q4_1                  0x1074a2080
# ggml_metal_init: loaded kernel_get_rows_q2_K                  0x1074a2800
# ggml_metal_init: loaded kernel_get_rows_q3_K                  0x1074a2f40
# ggml_metal_init: loaded kernel_get_rows_q4_K                  0x1074a3650
# ggml_metal_init: loaded kernel_get_rows_q5_K                  0x1074a3d90
# ggml_metal_init: loaded kernel_get_rows_q6_K                  0x1074a44d0
# ggml_metal_init: loaded kernel_rms_norm                       0x1074a4c20
# ggml_metal_init: loaded kernel_norm                           0x1074a5360
# ggml_metal_init: loaded kernel_mul_mat_f16_f32                0x1074a5d00
# ggml_metal_init: loaded kernel_mul_mat_q4_0_f32               0x1074a6540
# ggml_metal_init: loaded kernel_mul_mat_q4_1_f32               0x1073a9f90
# ggml_metal_init: loaded kernel_mul_mat_q2_K_f32               0x1073aa7e0
# ggml_metal_init: loaded kernel_mul_mat_q3_K_f32               0x1073aac80
# ggml_metal_init: loaded kernel_mul_mat_q4_K_f32               0x1073ab6b0
# ggml_metal_init: loaded kernel_mul_mat_q5_K_f32               0x1073ac6d0
# ggml_metal_init: loaded kernel_mul_mat_q6_K_f32               0x1073ad8c0
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                 0x1073ae3d0
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                0x1073aebd0
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                0x1073af450
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                0x1073afc50
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                0x1073b0480
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                0x1073b0d00
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                0x1073b1500
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                0x1073b1d80
# ggml_metal_init: loaded kernel_rope                           0x1073b2330
# ggml_metal_init: loaded kernel_alibi_f32                      0x1073b2d20
# ggml_metal_init: loaded kernel_cpy_f32_f16                    0x1073b3620
# ggml_metal_init: loaded kernel_cpy_f32_f32                    0x1073b3f10
# ggml_metal_init: loaded kernel_cpy_f16_f16                    0x1073b4880
# ggml_metal_init: recommendedMaxWorkingSetSize = 49152.00 MB
# ggml_metal_init: hasUnifiedMemory             = true
# ggml_metal_init: maxTransferRate              = built-in GPU
# llama_new_context_with_model: compute buffer total size =  418.85 MB
# llama_new_context_with_model: max tensor size =   102.54 MB
# ggml_metal_add_buffer: allocated 'data            ' buffer, size =  4435.94 MB, ( 4436.38 / 49152.00)
# ggml_metal_add_buffer: allocated 'eval            ' buffer, size =     1.36 MB, ( 4437.73 / 49152.00)
# ggml_metal_add_buffer: allocated 'kv              ' buffer, size =  3022.00 MB, ( 7459.73 / 49152.00)
# ggml_metal_add_buffer: allocated 'alloc           ' buffer, size =   417.52 MB, ( 7877.25 / 49152.00)
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | VSX = 0 |
# llama.cpp: loading model from ./models/Llama2/llama-2-7b-chat.ggmlv3.q5_K_S.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 6040
# llama_model_load_internal: n_embd     = 4096
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 32
# llama_model_load_internal: n_head_kv  = 32
# llama_model_load_internal: n_layer    = 32
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: n_gqa      = 1
# llama_model_load_internal: rnorm_eps  = 5.0e-06
# llama_model_load_internal: n_ff       = 11008
# llama_model_load_internal: freq_base  = 10000.0
# llama_model_load_internal: freq_scale = 1
# llama_model_load_internal: ftype      = 16 (mostly Q5_K - Small)
# llama_model_load_internal: model size = 7B
# llama_model_load_internal: ggml ctx size =    0.08 MB
# llama_model_load_internal: mem required  = 4435.58 MB (+ 3020.00 MB per state)
# llama_new_context_with_model: kv self size  = 3020.00 MB
# ggml_metal_init: allocating
# ggml_metal_init: loading '/Users/jpatel2/miniconda3/lib/python3.9/site-packages/llama_cpp/ggml-metal.metal'
# ggml_metal_init: loaded kernel_add                            0x107e3a800
# ggml_metal_init: loaded kernel_add_row                        0x107e3bd10
# ggml_metal_init: loaded kernel_mul                            0x107e3ca20
# ggml_metal_init: loaded kernel_mul_row                        0x107e3d080
# ggml_metal_init: loaded kernel_scale                          0x107e42d80
# ggml_metal_init: loaded kernel_silu                           0x107e43410
# ggml_metal_init: loaded kernel_relu                           0x107e3bf70
# ggml_metal_init: loaded kernel_gelu                           0x102c7aa90
# ggml_metal_init: loaded kernel_soft_max                       0x102c7b3b0
# ggml_metal_init: loaded kernel_diag_mask_inf                  0x102c7bc60
# ggml_metal_init: loaded kernel_get_rows_f16                   0x102c7c8a0
# ggml_metal_init: loaded kernel_get_rows_q4_0                  0x102c7ce50
# ggml_metal_init: loaded kernel_get_rows_q4_1                  0x102c7b930
# ggml_metal_init: loaded kernel_get_rows_q2_K                  0x102c7deb0
# ggml_metal_init: loaded kernel_get_rows_q3_K                  0x102c7e5a0
# ggml_metal_init: loaded kernel_get_rows_q4_K                  0x102c7ed30
# ggml_metal_init: loaded kernel_get_rows_q5_K                  0x102c7fbb0
# ggml_metal_init: loaded kernel_get_rows_q6_K                  0x102c802e0
# ggml_metal_init: loaded kernel_rms_norm                       0x102c80a30
# ggml_metal_init: loaded kernel_norm                           0x102c81170
# ggml_metal_init: loaded kernel_mul_mat_f16_f32                0x102c81b30
# ggml_metal_init: loaded kernel_mul_mat_q4_0_f32               0x102c82370
# ggml_metal_init: loaded kernel_mul_mat_q4_1_f32               0x102c82bb0
# ggml_metal_init: loaded kernel_mul_mat_q2_K_f32               0x102c83570
# ggml_metal_init: loaded kernel_mul_mat_q3_K_f32               0x102c83d20
# ggml_metal_init: loaded kernel_mul_mat_q4_K_f32               0x102c84590
# ggml_metal_init: loaded kernel_mul_mat_q5_K_f32               0x102c84e00
# ggml_metal_init: loaded kernel_mul_mat_q6_K_f32               0x102c85780
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                 0x102c86290
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                0x102c86b30
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                0x102c87330
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                0x102c87bd0
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                0x102c88400
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                0x102c88c30
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                0x102c894a0
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                0x102c89cd0
# ggml_metal_init: loaded kernel_rope                           0x102c8a2f0
# ggml_metal_init: loaded kernel_alibi_f32                      0x102c8ace0
# ggml_metal_init: loaded kernel_cpy_f32_f16                    0x102c8b5e0
# ggml_metal_init: loaded kernel_cpy_f32_f32                    0x102c8bf50
# ggml_metal_init: loaded kernel_cpy_f16_f16                    0x102c8c840
# ggml_metal_init: recommendedMaxWorkingSetSize = 49152.00 MB
# ggml_metal_init: hasUnifiedMemory             = true
# ggml_metal_init: maxTransferRate              = built-in GPU
# llama_new_context_with_model: compute buffer total size =  418.85 MB
# llama_new_context_with_model: max tensor size =   102.54 MB
# ggml_metal_add_buffer: allocated 'data            ' buffer, size =  4435.94 MB, ( 4436.38 / 49152.00)
# ggml_metal_add_buffer: allocated 'eval            ' buffer, size =     1.36 MB, ( 4437.73 / 49152.00)
# ggml_metal_add_buffer: allocated 'kv              ' buffer, size =  3022.00 MB, ( 7459.73 / 49152.00)
# ggml_metal_add_buffer: allocated 'alloc           ' buffer, size =   417.52 MB, ( 7877.25 / 49152.00)
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | VSX = 0 |
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
#
# You have 1 unapplied migration(s). Your project may not work properly until you apply the migrations for app(s): sessions.
# Run 'python manage.py migrate' to apply them.
# September 13, 2023 - 19:28:30
# Django version 3.2.21, using settings 'django_app.settings'
# Starting development server at http://0.0.0.0:9000/
# Quit the server with CONTROL-C.
# [13/Sep/2023 19:28:34] "GET / HTTP/1.1" 200 790
# ^C
